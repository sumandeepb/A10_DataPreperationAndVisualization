# %% [markdown]
# # Data Scraping

# %%
import scrapy
from scrapy.spiders import CrawlSpider, Rule
from scrapy.linkextractors import LinkExtractor
from scrapy.selector import Selector
import re
import json
from scrapy.http import Request, FormRequest
from collections import namedtuple
import re

class CricInfoScrapeSpider(scrapy.Spider):
    name='cricinfo-spider'
    start_urls=['http://www.espncricinfo.com/ci/content/player/country.html?country=6;alpha=A']
    first_class_batting_stats=namedtuple("first_batting_stats", 'matches, inns, not_outs, runs, highest, average, balls_faced, strike_rate, hundreds, fifties, boundaries, sixes, catches_taken, stumpings_made')

    def parse(self, response):
        sel = Selector(text=response.body_as_unicode(), type="html")
        players_urlpath=sel.xpath(
            '//div[@id="ciPlayerbyCharAtoZ"]//ul//li//a/@href'
        )
        for url in players_urlpath.extract()[1:-1]:
            url = "http://www.espncricinfo.com" + url
            request = scrapy.Request(url, self.parse_player_names)
            yield request

    def parse_player_names(self,response):
        sel= Selector(text=response.body_as_unicode(), type="html")
        urlPath=sel.xpath(
            '//td[@class="ciPlayernames"]//a/@href'
        )

        for url in urlPath.extract()[1:10]:
            url = "http://www.espncricinfo.com" + url
            request = scrapy.Request(url, self.parse_player_details)
            request.meta['url']=url
            yield request

    def parse_player_details(self, response):
        sel = Selector(text=response.body_as_unicode(), type="html")
        name = sel.xpath(
            '//div[@class="ciPlayernametxt"]/div/h1/text()'
        )

        dob_place=sel.xpath(
            '//p[@class="ciPlayerinformationtxt"]/b[contains(text(), "Born")]/following-sibling::span/text()'
        )

        teams=sel.xpath(
            '//p[@class="ciPlayerinformationtxt"]/b[contains(text(), "Major teams")]/following-sibling::span/text()'
        )
        self.first_class_batting_stats.matches=sel.xpath(
            '//*[@id="ciHomeContentlhs"]/div[4]/table[1]/tbody/tr[1]/td[2]/text()'
        )

        self.first_class_batting_stats.inns = sel.xpath(
            '//*[@id="ciHomeContentlhs"]/div[4]/table[1]/tbody/tr[1]/td[3]/text()'
        )

        self.first_class_batting_stats.not_outs = sel.xpath(
            '//*[@id="ciHomeContentlhs"]/div[4]/table[1]/tbody/tr[1]/td[4]/text()'
        )

        self.first_class_batting_stats.runs = sel.xpath(
            '//*[@id="ciHomeContentlhs"]/div[4]/table[1]/tbody/tr[1]/td[5]/text()'
        )

        self.first_class_batting_stats.highest = sel.xpath(
            '//*[@id="ciHomeContentlhs"]/div[4]/table[1]/tbody/tr[1]/td[6]/text()'
        )

        self.first_class_batting_stats.average = sel.xpath(
            '//*[@id="ciHomeContentlhs"]/div[4]/table[1]/tbody/tr[1]/td[7]/text()'
        )

        self.first_class_batting_stats.balls_faced = sel.xpath(
            '//*[@id="ciHomeContentlhs"]/div[4]/table[1]/tbody/tr[1]/td[8]/text()'
        )

        self.first_class_batting_stats.strike_rate = sel.xpath(
            '//*[@id="ciHomeContentlhs"]/div[4]/table[1]/tbody/tr[1]/td[9]/text()'
        )

        self.first_class_batting_stats.hundreds = sel.xpath(
            '//*[@id="ciHomeContentlhs"]/div[4]/table[1]/tbody/tr[1]/td[10]/text()'
        )

        self.first_class_batting_stats.fifties = sel.xpath(
            '//*[@id="ciHomeContentlhs"]/div[4]/table[1]/tbody/tr[1]/td[11]/text()'
        )

        self.first_class_batting_stats.boundaries = sel.xpath(
            '//*[@id="ciHomeContentlhs"]/div[4]/table[1]/tbody/tr[1]/td[12]/text()'
        )

        self.first_class_batting_stats.sixes = sel.xpath(
            '//*[@id="ciHomeContentlhs"]/div[4]/table[1]/tbody/tr[1]/td[13]/text()'
        )

        self.first_class_batting_stats.catches_taken = sel.xpath(
            '//*[@id="ciHomeContentlhs"]/div[4]/table[1]/tbody/tr[1]/td[14]/text()'
        )

        self.first_class_batting_stats.stumpings_made = sel.xpath(
            '//*[@id="ciHomeContentlhs"]/div[4]/table[1]/tbody/tr[1]/td[15]/text()'
        )

        json_stats= {
            "matches": re.sub('\s+','',self.first_class_batting_stats.matches.extract()[0]),
            "inns":re.sub('\s+','',self.first_class_batting_stats.inns.extract()[0]),
            "not_outs":re.sub('\s+','',self.first_class_batting_stats.not_outs.extract()[0]),
            "runs":re.sub('\s+','',self.first_class_batting_stats.runs.extract()[0]),
            "highest":re.sub('\s+','',self.first_class_batting_stats.highest.extract()[0]),
            "average":re.sub('\s+','',self.first_class_batting_stats.average.extract()[0]),
            "balls_faced":re.sub('\s+','',self.first_class_batting_stats.balls_faced.extract()[0]),
            "strike_rate":re.sub('\s+','',self.first_class_batting_stats.strike_rate.extract()[0]),
            "hundreds":re.sub('\s+','',self.first_class_batting_stats.hundreds.extract()[0]),
            "fifties":re.sub('\s+','',self.first_class_batting_stats.fifties.extract()[0]),
            "boundaries":re.sub('\s+','',self.first_class_batting_stats.boundaries.extract()[0]),
            "sixes":re.sub('\s+','',self.first_class_batting_stats.sixes.extract()[0]),
            "catches_taken":re.sub('\s+','',self.first_class_batting_stats.catches_taken.extract()[0]),
            "stumps":re.sub('\s+','',self.first_class_batting_stats.stumpings_made.extract()[0])
        }

        yield {
            "name": name.extract()[0].replace('\n',''),
            "url": response.meta['url'].replace('\n',''),
            "born": dob_place.extract()[0].replace('\n',''),
            "teams": teams.extract()[0].replace('\n',''),
            "first_class": json_stats

        }

# %% [markdown]
# # run it using the following command. Save the above code in cricinfo.py
# scrapy runspider -o players.csv cricinfo.py -t csv

# %%
import pandas as pd
import json

# %%
players_scraped = pd.read_csv("playerLinks.csv")

# %%
players_scraped['first_class'] = players_scraped['first_class'].apply(lambda x: json.loads(x.replace("'", "\"")))

# %%
df1 = pd.DataFrame(players_scraped['first_class'].values.tolist())
df1.columns = 'first_class.' + df1.columns

# %%
players_scraped
# Out:
#                         name  \
# 0           Abhisek Banerjee
# 1               Reagan Pinto
# 2               Anupam Patel
# 3              Utkarsh Patel
# 4                  Penta Rao
# 5          Pratharesh Parmar
# 6                Mehul Patel
# 7            Adithya B Sagar
# 8        Jagannathan Kaushik
# 9            Mohammed Khader
# 10         Dharshan Kanjania
# 11   Alpesh Kantilal Kamalia
# 12            Mohammad Karim
# 13               Madhu Kamat
# 14                 G Gurkude
# 15            Prashant Gupta
# 16            Gaurav Gambhir
# 17      Saurabh Suresh Gawde
# 18                 Shyam Gan
# 19             Mudassar Gani
# 20              Priyank Huda
# 21               Aryan Juyal
# 22               Aditya Jain
# 23             Nikunj Mohite
# 78       September 6, 1995, Dehra Dun, Uttar Pradesh
# 79                                September 17, 1994
# 80             December 27, 1989, Belgaum, Karnataka
# 81                      August 29, 1988, Mapusa, Goa
# 82               June 7, 1984, Bhavnagar, Saurashtra
# 83                                May 1, 1984, Delhi
# 84                                      date unknown
# 85                              May 18, 1989, Mumbai
# 86                           July 25, 1987, Guwahati
# 87                                  November 5, 1983
#
#                              teams  \
# 0                          Bengal,
# 1                              Goa
# 2                          Gujarat
# 3                           Baroda
# 4                         Services
# 5                          Gujarat
# 6   Gujarat Cricket Association XI
# 7                        Karnataka
# 8            Ruby Trichy Warriors,
# 9                Hyderabad (India)
# 10                           Delhi
# 11                      Saurashtra
# 12                        Vidarbha
# 13                             Goa
# 14                     Maharashtra
# 15                   Uttar Pradesh
# 16                          Punjab
# 17                             Goa
# 18                         Tripura
# 19                 Jammu & Kashmir
# 20                         Haryana
# 21                 India Under-19s
# 22                 Delhi Under-16s
# 23                          Baroda
# 24                        Vidarbha
# 25                        Vidarbha
# 26                          Orissa
# 27                          Orissa
# 28                       Rajasthan
# 29                          Orissa
# ..                             ...
# 58                 Jammu & Kashmir
# 59                          Baroda
# 60                          Andhra
# 61               Hyderabad (India)
# 62                 Jammu & Kashmir
# 63                      Saurashtra
# 64                Jammu & Kashmir,
# 65                 Jammu & Kashmir
# 66                Jammu & Kashmir,
# 67              Hyderabad (India),
# 68                       Rajasthan
# 69                          India,
# 70                          Andhra
# 71                      Puducherry
# 72                         Haryana
# 73                    Maharashtra,
# 74                         Tripura
# 75                          Mumbai
# 76               Delhi Daredevils,
# 77                         Haryana
# 78                         Bengal,
# 79                            Goa,
# 80                             Goa
# 81                             Goa
# 82                      Saurashtra
# 83                           Assam
# 84                   Uttar Pradesh
# 85               Mumbai Under-15s,
# 86                           Assam
# 87                        Vidarbha
#
#                                           first_class
# 0   {'matches': '4', 'inns': '4', 'not_outs': '0',...
# 1   {'matches': '31', 'inns': '47', 'not_outs': '4...
# 2   {'matches': '2', 'inns': '1', 'not_outs': '1',...
# 3   {'matches': '7', 'inns': '10', 'not_outs': '2'...
# 4   {'matches': '3', 'inns': '5', 'not_outs': '1',...
# 5   {'matches': '12', 'inns': '19', 'not_outs': '4...
# 6   {'matches': '18', 'inns': '23', 'not_outs': '6...
# 7   {'matches': '2', 'inns': '3', 'not_outs': '1',...
# 8   {'matches': '16', 'inns': '16', 'not_outs': '4...
# 9   {'matches': '16', 'inns': '19', 'not_outs': '6...
# 10  {'matches': '1', 'inns': '1', 'not_outs': '1',...
# 11  {'matches': '2', 'inns': '2', 'not_outs': '1',...
# 12  {'matches': '3', 'inns': '2', 'not_outs': '1',...
# 13  {'matches': '1', 'inns': '-', 'not_outs': '-',...
# 14  {'matches': '2', 'inns': '2', 'not_outs': '1',...
# 15  {'matches': '21', 'inns': '34', 'not_outs': '0...
# 16  {'matches': '2', 'inns': '4', 'not_outs': '1',...
# 17  {'matches': '3', 'inns': '2', 'not_outs': '0',...
# 18  {'matches': '5', 'inns': '5', 'not_outs': '1',...
# 19  {'matches': '1', 'inns': '1', 'not_outs': '1',...
# 20  {'matches': '2', 'inns': '3', 'not_outs': '1',...
# 21  {'matches': '3', 'inns': '3', 'not_outs': '0',...
# 22  {'matches': '16', 'inns': '22', 'not_outs': '2...
# 23  {'matches': '1', 'inns': '1', 'not_outs': '0',...
# 24  {'matches': '3', 'inns': '5', 'not_outs': '1',...
# 25  {'matches': '44', 'inns': '69', 'not_outs': '3...
# 26  {'matches': '1', 'inns': '2', 'not_outs': '0',...
# 27  {'matches': '1', 'inns': '1', 'not_outs': '0',...
# 28  {'matches': '3', 'inns': '6', 'not_outs': '0',...
# 29  {'matches': '91', 'inns': '126', 'not_outs': '...
# ..                                                ...
# 58  {'matches': '8', 'inns': '8', 'not_outs': '0',...
# 59  {'matches': '8', 'inns': '11', 'not_outs': '6'...
# 60  {'matches': '1', 'inns': '2', 'not_outs': '0',...
# 61  {'matches': '12', 'inns': '17', 'not_outs': '3...
# 62  {'matches': '1', 'inns': '1', 'not_outs': '0',...
# 63  {'matches': '53', 'inns': '86', 'not_outs': '6...
# 64  {'matches': '2', 'inns': '2', 'not_outs': '0',...
# 65  {'matches': '1', 'inns': '2', 'not_outs': '0',...
# 66  {'matches': '2', 'inns': '2', 'not_outs': '0',...
# 67  {'matches': '14', 'inns': '19', 'not_outs': '6...
# 68  {'matches': '4', 'inns': '7', 'not_outs': '3',...
# 69  {'matches': '4', 'inns': '6', 'not_outs': '1',...
# 70  {'matches': '4', 'inns': '4', 'not_outs': '2',...
# 71  {'matches': '1', 'inns': '-', 'not_outs': '-',...
# 72  {'matches': '11', 'inns': '16', 'not_outs': '8...
# 73  {'matches': '22', 'inns': '40', 'not_outs': '2...
# 74  {'matches': '3', 'inns': '6', 'not_outs': '1',...
# 75  {'matches': '1', 'inns': '2', 'not_outs': '2',...
# 76  {'matches': '90', 'inns': '140', 'not_outs': '...
# 77  {'matches': '3', 'inns': '3', 'not_outs': '1',...
# 78  {'matches': '44', 'inns': '77', 'not_outs': '7...
# 79  {'matches': '5', 'inns': '3', 'not_outs': '3',...
# 80  {'matches': '1', 'inns': '2', 'not_outs': '0',...
# 81  {'matches': '6', 'inns': '8', 'not_outs': '0',...
# 82  {'matches': '6', 'inns': '10', 'not_outs': '0'...
# 83  {'matches': '9', 'inns': '17', 'not_outs': '1'...
# 84  {'matches': '2', 'inns': '-', 'not_outs': '-',...
# 85  {'matches': '2', 'inns': '3', 'not_outs': '0',...
# 86  {'matches': '5', 'inns': '8', 'not_outs': '1',...
# 87  {'matches': '1', 'inns': '2', 'not_outs': '0',...
#
# [88 rows x 5 columns]

# %%
final_df = pd.concat([players_scraped.drop(columns="first_class"), df1], axis=1)

# %%
final_df
# Out:
#                         name  \
# 0           Abhisek Banerjee
# 1               Reagan Pinto
# 2               Anupam Patel
# 3              Utkarsh Patel
# 4                  Penta Rao
# 5          Pratharesh Parmar
# 6                Mehul Patel
# 7            Adithya B Sagar
# 8        Jagannathan Kaushik
# 9            Mohammed Khader
# 10         Dharshan Kanjania
# 11   Alpesh Kantilal Kamalia
# 12            Mohammad Karim
# 13               Madhu Kamat
# 14                 G Gurkude
# 15            Prashant Gupta
# 16            Gaurav Gambhir
# 17      Saurabh Suresh Gawde
# 74                           April 2, 1987, Agartala
# 75                        September 30, 1987, Mumbai
# 76             December 17, 1992, Paitha, Aurangabad
# 77                                      date unknown
# 78       September 6, 1995, Dehra Dun, Uttar Pradesh
# 79                                September 17, 1994
# 80             December 27, 1989, Belgaum, Karnataka
# 81                      August 29, 1988, Mapusa, Goa
# 82               June 7, 1984, Bhavnagar, Saurashtra
# 83                                May 1, 1984, Delhi
# 84                                      date unknown
# 85                              May 18, 1989, Mumbai
# 86                           July 25, 1987, Guwahati
# 87                                  November 5, 1983
#
#                              teams first_class.average  \
# 0                          Bengal,               23.75
# 1                              Goa               32.55
# 2                          Gujarat                   -
# 3                           Baroda               20.75
# 4                         Services               34.50
# 5                          Gujarat               38.33
# 6   Gujarat Cricket Association XI               16.11
# 7                        Karnataka               24.50
# 8            Ruby Trichy Warriors,                7.00
# 9                Hyderabad (India)               19.30
# 10                           Delhi                   -
# 11                      Saurashtra               19.00
# 12                        Vidarbha               36.00
# 13                             Goa                   -
# 14                     Maharashtra               27.00
# 15                   Uttar Pradesh               25.85
# 16                          Punjab               39.33
# 17                             Goa               12.50
# 18                         Tripura               23.25
# 19                 Jammu & Kashmir                   -
# 20                         Haryana                3.50
# 21                 India Under-19s               32.33
# 22                 Delhi Under-16s                28.1
# 23                          Baroda                7.00
# 24                        Vidarbha               38.50
# 25                        Vidarbha               26.25
# 26                          Orissa                3.00
# 27                          Orissa               19.00
# 28                       Rajasthan               18.83
# 29                          Orissa               13.31
# ..                             ...                 ...
# 58                 Jammu & Kashmir               37.62
# 59                          Baroda                7.00
# 60                          Andhra                0.00
# 61               Hyderabad (India)               11.07
# 62                 Jammu & Kashmir                   0
# 63                      Saurashtra               33.88
# 64                Jammu & Kashmir,               15.00
# 65                 Jammu & Kashmir               12.00
# 66                Jammu & Kashmir,                3.00
# 67              Hyderabad (India),                9.23
# 68                       Rajasthan                9.50
# 69                          India,               45.60
# 70                          Andhra               38.00
# 71                      Puducherry                   -
# 72                         Haryana               10.62
# 73                    Maharashtra,               22.60
# 74                         Tripura               10.00
# 75                          Mumbai                   -
# 76               Delhi Daredevils,               50.34
# 77                         Haryana                  42
# 78                         Bengal,               50.25
# 79                            Goa,                   -
# 80                             Goa               12.50
# 81                             Goa                7.50
# 82                      Saurashtra               21.70
# 83                           Assam               19.43
# 84                   Uttar Pradesh                   -
# 85               Mumbai Under-15s,               22.00
# 86                           Assam                8.71
# 87                        Vidarbha                3.00
#
#    first_class.balls_faced first_class.boundaries first_class.catches_taken  \
# 0                      122                     14                         2
# 1                     2772                    159                        11
# 2                        0                      0                         0
# 3                      321                     21                         3
# 4                      314                     14                         0
# 5                     1546                     53                        12
# 6                      703                     33                         5
# 7                      140                      7                         1
# 8                      312                      6                         2
# 9                      691                     36                         6
# 10                       4                      0                         0
# 11                      26                      1                         1
# 12                      60                      3                         1
# 13                       -                      -                         0
# 14                      27                      1                         2
# 15                    1932                    120                        25
# 16                     306                     12                         0
# 17                      42                      1                         0
# 18                      94                      8                         2
# 19                       4                      0                         1
# 20                      29                      0                         0
# 21                     128                      8                         1
# 22                    1488                     74                        11
# 23                      32                      0                         0
# 24                     264                     17                         3
# 25                    4380                    216                        28
# 26                       9                      1                         1
# 27                      38                      1                         0
# 28                     210                     18                         1
# 29                    2776                    177                        21
# ..                     ...                    ...                       ...
# 58                     449                     33                         1
# 59                      49                      7                         0
# 60                       3                      0                         0
# 61                     474                     13                         7
# 62                       2                      0                         0
# 63                    6903                    330                        57
# 64                      52                      1                         1
# 65                      34                      4                         1
# 66                      11                      1                         0
# 67                     455                     13                         2
# 68                     141                      3                         1
# 69                     515                     28                         1
# 70                     102                      4                         2
# 71                       -                      -                         0
# 72                     228                      9                         3
# 73                    2291                    101                         6
# 74                     107                      9                         2
# 75                      40                      2                         0
# 76                   12762                    672                        39
# 77                     105                      4                         1
# 78                    6979                    418                        42
# 79                      12                      2                         0
# 80                      97                      2                         0
# 81                     173                      8                         3
# 82                     577                     32                         1
# 83                     832                     30                         6
# 84                       -                      -                         1
# 85                     103                     10                         2
# 86                     151                      6                         1
# 87                      18                      0                         1
#
#    first_class.fifties first_class.highest first_class.hundreds  \
# 0                    1                  68                    0
# 1                    7                 154                    3
# 2                    0                  0*                    0
# 3                    1                  53                    0
# 4                    1                  89                    0
# 5                    5                  67                    0
# 6                    1                  62                    0
# 7                    0                  29                    0
# 8                    0                  20                    0
# 9                    0                 35*                    0
# 10                   0                  1*                    0
# 11                   0                  17                    0
# 12                   0                  33                    0
# 13                   -                   -                    -
# 14                   0                 23*                    0
# 15                   3                 144                    1
# 16                   1                 50*                    0
# 17                   0                  22                    0
# 18                   0                  35                    0
# 19                   0                  2*                    0
# 20                   0                   5                    0
# 21                   1                  69                    0
# 22                   4                  76                    0
# 23                   0                   7                    0
# 24                   0                  49                    0
# 25                   8                 110                    3
# 26                   0                   6                    0
# 27                   0                  19                    0
# 28                   1                  68                    0
# 29                   2                 60*                    0
# ..                 ...                 ...                  ...
# 58                   1                 117                    1
# 59                   0                 10*                    0
# 60                   0                   0                    0
# 61                   0                  37                    0
# 62                   0                   0                    0
# 63                  16                 205                    4
# 64                   0                  30                    0
# 65                   0                  24                    0
# 66                   0                   5                    0
# 67                   0                 28*                    0
# 68                   0                  15                    0
# 69                   1                 104                    1
# 70                   0                 28*                    0
# 71                   -                   -                    -
# 72                   0                  20                    0
# 73                   5                  82                    0
# 74                   0                  27                    0
# 75                   0                  8*                    0
# 76                  32                258*                   17
# 77                   1                  52                    0
# 78                  16                201*                   11
# 79                   0                 13*                    0
# 80                   0                  13                    0
# 81                   0                  37                    0
# 82                   1                  65                    0
# 83                   0                  46                    0
# 84                   -                   -                    -
# 85                   1                  65                    0
# 86                   0                  22                    0
# 87                   0                   4                    0
#
#    first_class.inns first_class.matches first_class.not_outs first_class.runs  \
# 0                 4                   4                    0               95
# 1                47                  31                    4             1400
# 2                 1                   2                    1                0
# 3                10                   7                    2              166
# 4                 5                   3                    1              138
# 5                19                  12                    4              575
# 6                23                  18                    6              274
# 7                 3                   2                    1               49
# 8                16                  16                    4               84
# 9                19                  16                    6              251
# 10                1                   1                    1                1
# 11                2                   2                    1               19
# 12                2                   3                    1               36
# 13                -                   1                    -                -
# 14                2                   2                    1               27
# 15               34                  21                    0              879
# 16                4                   2                    1              118
# 17                2                   3                    0               25
# 18                5                   5                    1               93
# 19                1                   1                    1                2
# 20                3                   2                    1                7
# 21                3                   3                    0               97
# 22               22                  16                    2              562
# 23                1                   1                    0                7
# 24                5                   3                    1              154
# 25               69                  44                    3             1733
# 26                2                   1                    0                6
# 27                1                   1                    0               19
# 28                6                   3                    0              113
# 29              126                  91                   37             1185
# ..              ...                 ...                  ...              ...
# 58                8                   8                    0              301
# 59               11                   8                    6               35
# 60                2                   1                    0                0
# 61               17                  12                    3              155
# 62                1                   1                    0                0
# 63               86                  53                    6             2711
# 64                2                   2                    0               30
# 65                2                   1                    0               24
# 66                2                   2                    0                6
# 67               19                  14                    6              120
# 68                7                   4                    3               38
# 69                6                   4                    1              228
# 70                4                   4                    2               76
# 71                -                   1                    -                -
# 72               16                  11                    8               85
# 73               40                  22                    2              859
# 74                6                   3                    1               50
# 75                2                   1                    2               12
# 76              140                  90                   23             5890
# 77                3                   3                    1               84
# 78               77                  44                    7             3518
# 79                3                   5                    3               13
# 80                2                   1                    0               25
# 81                8                   6                    0               60
# 82               10                   6                    0              217
# 83               17                   9                    1              311
# 84                -                   2                    -                -
# 85                3                   2                    0               66
# 86                8                   5                    1               61
# 87                2                   1                    0                6
#
#    first_class.sixes first_class.strike_rate first_class.stumps
# 0                  0                   77.86                  0
# 1                 10                   50.50                  0
# 2                  0                       -                  0
# 3                  2                   51.71                  0
# 4                  0                   43.94                  0
# 5                  4                   37.19                  0
# 6                  8                   38.97                  0
# 7                  0                   35.00                  0
# 8                  2                   26.92                  0
# 9                  1                   36.32                  0
# 10                 0                   25.00                  0
# 11                 0                   73.07                  0
# 12                 0                   60.00                  0
# 13                 -                       -                  0
# 14                 0                  100.00                  0
# 15                 6                   45.49                  0
# 16                 0                   38.56                  0
# 17                 0                   59.52                  0
# 18                 1                   98.93                  0
# 19                 0                   50.00                  0
# 20                 0                   24.13                  0
# 21                 0                   75.78                  1
# 22                 0                   37.76                  0
# 23                 0                   21.87                  0
# 24                 0                   58.33                  0
# 25                 7                   39.56                  0
# 26                 0                   66.66                  0
# 27                 0                   50.00                  0
# 28                 0                   53.80                  0
# 29                 9                   42.68                  0
# ..               ...                     ...                ...
# 58                 6                   67.03                  0
# 59                 0                   71.42                  0
# 60                 0                    0.00                  0
# 61                 1                   32.70                  0
# 62                 0                       0                  0
# 63                 2                   39.27                  0
# 64                 2                   57.69                  0
# 65                 0                   70.58                  0
# 66                 0                   54.54                  0
# 67                 0                   26.37                  0
# 68                 0                   26.95                  0
# 69                 0                   44.27                  0
# 70                 0                   74.50                  0
# 71                 -                       -                  0
# 72                 0                   37.28                  0
# 73                 4                   37.49                  0
# 74                 0                   46.72                  0
# 75                 0                   30.00                  0
# 76                58                   46.15                  0
# 77                 0                      80                  0
# 78                11                   50.40                  0
# 79                 0                  108.33                  0
# 80                 1                   25.77                  0
# 81                 0                   34.68                  0
# 82                 0                   37.60                  0
# 83                 3                   37.37                  0
# 84                 -                       -                  0
# 85                 0                   64.07                  0
# 86                 1                   40.39                  0
# 87                 0                   33.33                  0
#
# [88 rows x 18 columns]
